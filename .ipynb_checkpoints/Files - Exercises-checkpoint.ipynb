# %% [markdown]
# ## Lab: Files

# %% [markdown]
# **Learning Objectives**
# * To read from (and write to) a text file to solve problems, as appropriate.
# * To write Python code that successfully implements the solution to a problem by combining the manipulation of text files with previously covered concepts, e.g. loops, and dictionaries.
#
# **General notes about the exercises**
# * You should attempt the exercises below by using *only* the Python constructs that you learnt up to the end of topic **Files**.
# * Spend a few minutes before you write code, to think about how to structure your proposed solution.
# * Add comments to your code.
# * Make your code neat, by using indentation and parentheses (where appropriate).
# * Give meaningful names to functions and variables.
# * You may find it easier to do some of these exercises directly in the notebook. Feel free to insert text with your comments or write your notes as you proceed. The Jupyter Notebook is "yours for keeps".

# %% [markdown]
# ### 1 - Simple notepad

# %% [markdown]
# Write a script called ```takenote.py``` that keeps asking the user for text and writes it to a file called ```notes.txt``` one line at a time, until the user writes the word ```exit``` alone on a line. This word should not be saved.
#
# Then  write a script called ```shownotes.py``` that prints the contents of ```notes.txt``` to the screen.
#
# Note that each time you run ```takenote.py```  file ```notes.txt``` is cleared. To avoid this, modify ```takenote.py``` so that it opens the file for appending instead than for writing - simply change 'w' into 'a' in the ```open()``` statement.

# %%
file = input("choose filename for appending: ")
while True:
    note = input("Please add text: ")
    if note == "exit":
        break
    else:
        notes = open(file, "a")
        notes.write(note)
        notes.write("\n")
notes.close()
# Out:
# choose filename for appending: my_csv.csv
# Please add text: milk,2.00
# Please add text: bananas,1.25
# Please add text: hamburger,4.95
# Please add text: chocolate,25.00
# Please add text: supplements,3.50
# Please add text: exit

# %% [markdown]
# ### 2 - Save your pennies

# %% [markdown]
# Write a program that reads a simple ```.csv``` file with the cost of shopping items. Your program should ask the user for the name of the file and print the total cost.
#
# An example input file should look like the one below:
# ```
# milk,2.00
# bananas,1.25
# hamburger,4.95
# chocolate,25.00
# supplements,3.50
# ```
# you can create one using the ```takenote.py``` program you wrote above, directly using a text editor on your local machine or clicking on ```New > Text File``` on the Jupyter Notebook directory tab.
#
# **Optional**: Add extra functionality to your program, such it is also prints a line that reads
# ```
# Savings tips: you could cut down on the [...]
# ```
# followed by the name of the *least* expensive item.

# %%
file = input("Choose a csv file to open: ")
csv_file = open(file, "r")
total = 0
min_number = 999
while True:
    line = csv_file.readline()
    if not line:
        break
    else:
        data = line.split(",")
        price = float(data[1])
        if price < min_number:
            min_number = price
            cut_down_on = data[0]
        total+= price
print(total)
print("you could cut down on the " + cut_down_on)
csv_file.close()
# Out:
# Choose a csv file to open: my_csv.csv
# 36.7
# you could cut down on the bananas

# %% [markdown]
# ### 3 - Small words

# %% [markdown]
# Write a program that reads in a list of words in a text file called **origWordsList.txt**, and copies all the words that are 5 letters long onto a new file called **shortWordsList.txt**; the program should also display a message if it cannot find any 5-letter words to store. Then improve your program by allowing the user to choose:
# 1. which file to read from (and write to);
# 2. what is the maximum number of characters of the words to store in the new file.
#
# **Note**: Try reading a text file (without whitespace at the start and end) by using a *list comprehension*, thus loading the file's lines into a list. For example, if you have a file called *anExample.txt*, you would write
# ```fileLines = [oneLine.strip() for oneLine in open('anExample.txt')]```.

# %%
readfrom = input("Which file do you want to read from? ")
writeto = input("Which file do you want to write to? ")
maxchar = int(input("What is the maximum number of characters of the words to store in the new file? "))

original_words = open(readfrom, "r")
short_words = open(writeto, "w")
count = 0
words = [word.strip() for word in open(readfrom)]
for word in words:
    if len(word) == maxchar:
        short_words.write(word + "\n")
        count += 1
if not count:
    print(f"No {maxchar} letter words")

original_words.close()
short_words.close()
# Out:
# Which file do you want to read from? origWordsList.txt
# Which file do you want to write to? sixLetterWords.txt
# What is the maximum number of characters of the words to store in the new file? 6

# %% [markdown]
# ### 4 - Large country, small country

# %% [markdown]
# Write a program that extracts the countries whose names start with the letter **P** which have at least 1 million people, from a text file called **visitedCountriesAndPopulation.txt**.
#
# **Hint**: Each line should be split around the tab character (*\t*).

# %%
filename = open("visitedCountriesAndPopulation.txt")
countries_and_pops = [line.rstrip().split("\t") for line in filename]
filename.close()
p_countries_with_pop_greater_than_1_mil = [item for item in countries_and_pops if item[0][0] == "P" and int(item[1]) > 1000000]
print(p_countries_with_pop_greater_than_1_mil)
# Out:
# [['Poland', '38496000'], ['Portugal', '10477800'], ['Palestine', '4550368']]

# %% [markdown]
# ### 5 - Counting characters per line

# %% [markdown]
# Write a program that asks the user for a filename, reads its contents and displays the number of characters (excluding spaces) per line.
#
# **Food for thought**: What do you think will happen if the filename typed by the user does not exist?

# %%
file = input("Please choose a file: ")
file = open(file)
line_char_lens = [len(line.replace(" ", "")) for line in file]
for char_len in line_char_lens:
    print(char_len)
file.close(0)
# Out:
# Please choose a file: origWordsList.txt
# 2
# 8
# 5
# 6
# 6
# 7
# 10
# 8
# 7
# 4
# 7
# 9
# 9
# 4
# 8
# 15
# 6
# 6
# 7
# 6
# 6
# 8
# 4
# 7
# 6
# 4
# 6
# 10
# 6
# 4
# 4
# 6
# 7
# 6
# 6
# 8
# 5
# 9
# 7
# 9
# 6
# 7
# 9
# 4
# 7
# 8
# 7
# 4
# 7
# 9
# 7
# 6
# 9
# 5
# 6
# 4
# 7
# 7
# 4
# 8
# 7
# 3
# 4
# 7
# 3
# 7
# 10
# 9
# 9
# 7
# 10
# 10
# 6
# 5
# 5
# 5
# 4
# 4
# 5
# 5
# 4
# 5
# 3
# 5
# 10
# 8
# 7
# 4
# 7
# 6
# 9
# 7
# 8
# 8
# 5
# 7
# 8
# 7
# 4
# 5
# 8
# 4
# 6
# 6
# 5
# 6
# 5
# 5
# 5
# 5
# 4
# 4
# 6
# 6
# 8
# 7
# 6
# 9
# 9
# 4
# 4
# 3
# 5
# 7
# 9
# 4
# 7
# 10
# 8
# 4
# 5
# 5
# 7
# 6
# 5
# 6
# 6
# 5
# 7
# 8
# 8
# 8
# 10
# 6
# 10
# 7
# 7
# 10
# 7
# 6
# 6
# 7
# 7
# 7
# 8
# 5
# 6
# 6
# 6
# 6
# 8
# 6
# 6
# 5
# 11
# 8
# 6
# 5
# 11
# 7
# 10
# 8
# 8
# 9
# 8
# 10
# 11
# 9
# 9
# 9
# 8
# 9
# 8
# 5
# 6
# 8
# 7
# 7
# 6
# 6
# 7
# 6
# 9
# 8
# 4
# 8
# 9
# 4
# 5
# 5
# 9
# 4
# 5
# 5
# 6
# 7
# 7
# 7
# 9
# 5
# 8
# 7
# 9
# 11
# 9
# 7
# 8
# 7
# 10
# 8
# 12
# 4
# 11
# 10
# 10
# 7
# 10
# 9
# 9
# 8
# 11
# 8
# 3
# 7
# 4
# 5
# 5
# 5
# 6
# 6
# 5
# 5
# 7
# 5
# 6
# 5
# 5
# 4
# 9
# 8
# 5
# 10
# 7
# 7
# 6
# 7
# 9
# 5
# 9
# 4
# 7
# 6
# 7
# 6
# 7
# 12
# 14
# 11
# 10
# 5
# 8
# 6
# 5
# 6
# 10
# 9
# 11
# 9
# 8
# 8
# 10
# 6
# 7
# 11
# 7
# 8
# 4
# 5
# 5
# 7
# 5
# 5
# 7
# 4
# 5
# 7
# 5
# 8
# 5
# 8
# 4
# 6
# 6
# 7
# 5
# 5
# 6
# 8
# 10
# 5
# 5
# 7
# 7
# 5
# 5
# 6
# 5
# 5
# 6
# 4
# 6
# 7
# 5
# 5
# 4
# 6
# 8
# 7
# 5
# 7
# 8
# 5
# 5
# 7
# 5
# 6
# 5
# 5
# 7
# 5
# 7
# 4
# 8
# 11
# 4
# 5
# 5
# 6
# 3
# 5
# 5
# 11
# 6
# 6
# 7
# 6
# 5
# 7
# 6
# 4
# 4
# 5
# 5
# 5
# 5
# 7
# 6
# 5
# 5
# 3
# 5
# 7
# 5
# 6
# 5
# 6
# 5
# 4
# 5
# 8
# 5
# 4
# 8
# 4
# 8
# 4
# 5
# 5
# 5
# 9
# 4
# 6
# 5
# 6
# 4
# 8
# 5
# 6
# 8
# 8
# 2
# 5
# 9
# 3
# 6
# 8
# 7
# 10
# 8
# 3
# 8
# 10
# 9
# 7
# 9
# 11
# 9
# 12
# 7
# 8
# 12
# 9
# 12
# 14
# 10
# 5
# 11
# 8
# 6
# 3
# 5
# 4
# 7
# 4
# 5
# 5
# 5
# 4
# 4
# 5
# 5
# 8
# 5
# 10
# 5
# 9
# 6
# 5
# 5
# 6
# 6
# 4
# 7
# 4
# 5
# 7
# 6
# 6
# 6
# 5
# 4
# 6
# 5
# 4
# 7
# 6
# 4
# 5
# 6
# 5
# 7
# 5
# 5
# 7
# 7
# 5
# 6
# 5
# 5
# 5
# 5
# 4
# 5
# 4
# 8
# 9
# 5
# 9
# 6
# 9
# 5
# 4
# 7
# 11
# 8
# 5
# 7
# 9
# 9
# 7
# 4
# 6
# 3
# 5
# 8
# 6
# 8
# 5
# 8
# 7
# 7
# 8
# 8
# 7
# 7
# 6
# 9
# 8
# 5
# 7
# 5
# 8
# 6
# 7
# 7
# 6
# 6
# 5
# 8
# 5
# 7
# 6
# 5
# 9
# 6
# 3
# 4
# 5
# 6
# 5
# 3
# 7
# 5
# 7
# 9
# 8
# 7
# 5
# 7
# 10
# 5
# 8
# 6
# 4
# 5
# 10
# 5
# 5
# 6
# 3
# 5
# 4
# 6
# 4
# 5
# 8
# 7
# 4
# 4
# 7
# 6
# 3
# 4
# 6
# 7
# 8
# 9
# 6
# 3
# 4
# 3
# 4
# 3
# 5
# 4
# 5
# 5
# 5
# 10
# 12
# 7
# 3
# 6
# 13
# 6
# 7
# 4
# 4
# 8
# 5
# 4
# 6
# 5
# 5
# 9
# 6
# 7
# 5
# 12
# 11
# 13
# 8
# 6
# 5
# 5
# 8
# 8
# 4
# 6
# 7
# 4
# 8
# 12
# 8
# 7
# 7
# 9
# 6
# 9
# 5
# 8
# 6
# 6
# 5
# 6
# 5
# 7
# 3
# 6
# 7
# 7
# 10
# 9
# 5
# 8
# 11
# 9
# 9
# 9
# 6
# 9
# 8
# 8
# 10
# 9
# 7
# 8
# 6
# 8
# 9
# 8
# 8
# 8
# 8
# 11
# 13
# 10
# 8
# 8
# 9
# 8
# 6
# 8
# 7
# 5
# 8
# 5
# 4
# 8
# 9
# 8
# 6
# 5
# 6
# 6
# 6
# 5
# 7
# 6
# 5
# 6
# 5
# 8
# 8
# 7
# 7
# 8
# 7
# 9
# 10
# 7
# 4
# 7
# 8
# 7
# 7
# 13
# 10
# 7
# 9
# 7
# 7
# 10
# 11
# 8
# 9
# 9
# 8
# 9
# 15
# 5
# 7
# 7
# 7
# 5
# 6
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 4
# 5
# 5
# 5
# 4
# 6
# 7
# 8
# 10
# 6
# 4
# 7
# 5
# 7
# 8
# 9
# 4
# 5
# 5
# 5
# 5
# 7
# 6
# 7
# 8
# 6
# 8
# 4
# 6
# 8
# 4
# 7
# 6
# 6
# 4
# 6
# 6
# 5
# 7
# 9
# 5
# 5
# 5
# 12
# 8
# 7
# 7
# 6
# 5
# 7
# 7
# 4
# 5
# 10
# 4
# 5
# 6
# 5
# 6
# 6
# 3
# 7
# 8
# 8
# 5
# 9
# 8
# 10
# 10
# 4
# 5
# 5
# 5
# 6
# 7
# 6
# 9
# 6
# 6
# 8
# 9
# 7
# 6
# 6
# 7
# 6
# 6
# 6
# 9
# 5
# 6
# 6
# 10
# 8
# 5
# 5
# 6
# 6
# 5
# 6
# 6
# 9
# 7
# 7
# 10
# 8
# 6
# 6
# 6
# 8
# 8
# 11
# 5
# 9
# 7
# 8
# 7
# 8
# 5
# 8
# 7
# 6
# 5
# 5
# 5
# 4
# 6
# 8
# 5
# 11
# 11
# 5
# 4
# 5
# 5
# 5
# 5
# 6
# 5
# 4
# 6
# 5
# 11
# 5
# 7
# 6
# 6
# 5
# 6
# 6
# 6
# 5
# 6
# 7
# 8
# 9
# 7
# 6
# 8
# 11
# 6
# 5
# 5
# 3
# 6
# 9
# 8
# 4
# 4
# 6
# 6
# 7
# 5
# 6
# 12
# 9
# 7
# 6
# 10
# 5
# 6
# 5
# 8
# 5
# 6
# 4
# 5
# 3
# 4
# 5
# 6
# 11
# 5
# 6
# 3
# 5
# 3
# 4
# 8
# 6
# 8
# 5
# 7
# 5
# 9
# 6
# 6
# 5
# 5
# 5
# 5
# 5
# 4
# 6
# 6
# 4
# 3
# 7
# 5
# 5
# 7
# 5
# 5
# 8
# 5
# 9
# 5
# 6
# 8
# 6
# 6
# 6
# 4
# 6
# 5
# 6
# 4
# 5
# 5
# 5
# 4
# 5
# 7
# 5
# 5
# 7
# 8
# 6
# 7
# 5
# 5
# 7
# 6
# 6
# 6
# 6
# 7
# 6
# 5
# 5
# 5
# 4
# 4
# 4
# 6
# 5
# 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-545bf1fe9264> in <module>
#       4 for char_len in line_char_lens:
#       5     print(char_len)
# ----> 6 file.close(0)
#
# TypeError: close() takes no arguments (1 given)
